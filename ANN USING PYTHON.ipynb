# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
from sklearn.neural_network import MLPClassifier
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
X_train, y_train = make_circles(n_samples=700, noise=0.05)
X_test, y_test = make_circles(n_samples=300, noise=0.05)

# %% [raw]
# # Load the dataset
# df = pd.read_csv("your_dataset.csv")  # Make sure the file path is correct
#
# # Separate features (X) and labels (y)
# X = df.drop('target_column', axis=1)  # Replace 'target_column' with the actual name of your label column
# y = df['target_column']  # Your label column
#
# # Split the data into training and test sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
sns.scatterplot(x=X_train[:,0], y=X_train[:,1], hue=y_train)
plt.title("Train Data")
plt.show()

# %%
clf = MLPClassifier(max_iter=999)
clf.fit(X_train, y_train)
# Out:
# C:\Users\Harish Ragavendar\miniconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (999) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(max_iter=999)

# %%
print(f"R2 Score for Training Data = {clf.score(X_train, y_train)}")
print(f"R2 Score for Test Data = {clf.score(X_test, y_test)}")
# Out:
# R2 Score for Training Data = 0.98
# R2 Score for Test Data = 0.98

# %%
y_pred = clf.predict(X_test)

# %%
fig, ax = plt.subplots(1, 2)
sns.scatterplot(x=X_test[:,0], y=X_test[:,1], hue=y_pred, ax=ax[0])
ax[0].title.set_text("Predicted Data")
sns.scatterplot(x=X_test[:,0], y=X_test[:,1], hue=y_test, ax=ax[1])
ax[1].title.set_text("Test Data")
plt.show()
