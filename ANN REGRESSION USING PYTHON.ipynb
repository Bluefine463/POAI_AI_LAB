# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [raw]
# # Load your dataset from a CSV file
# # Make sure the CSV file has a column for the target values (y) and others for features (X)
# df = pd.read_csv('your_dataset.csv')
#
# # Separate the features (X) and target (y)
# # Assuming the target column is named 'target' and the rest are features
# X = df.drop(columns=['target'])  # Drop the target column, keeping only the features
# y = df['target']  # This is the target column
#
# # Check the shape of the data (Optional)
# print(X.shape, y.shape)

# %%
# Import necessary libraries


# Generate a synthetic dataset for regression
X, y = make_regression(n_samples=1000, noise=0.05, n_features=100)

# Print the shape of the generated dataset
X.shape, y.shape = ((1000, 100), (1000,))

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)

# Create and train the MLPRegressor model
clf = MLPRegressor(max_iter=1000)
clf.fit(X_train, y_train)

# Print the R2 score for both training and test datasets
print(f"R2 Score for Training Data = {clf.score(X_train, y_train)}")
print(f"R2 Score for Test Data = {clf.score(X_test, y_test)}")

# Predict the target values for the test set
y_pred = clf.predict(X_test)

# Plotting the predicted values vs the actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5, color="b")
plt.plot([min(y_test), max(y_test)],[min(y_test), max(y_test)], color="r", lw=2)  # A reference line y=x
plt.title('Predicted vs Actual Values (Test Data)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# Visualize the residuals (errors)
residuals = y_test - y_pred
plt.figure(figsize=(8, 6))
sns.histplot(residuals, kde=True)
plt.title('Residuals Distribution')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()
# Out:
# R2 Score for Training Data = 0.9999556254347808
# R2 Score for Test Data = 0.9610942038534777
# C:\Users\Harish Ragavendar\miniconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
